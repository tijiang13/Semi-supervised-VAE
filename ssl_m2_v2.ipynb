# %%
# -*- coding: utf-8 -*-
from __future__ import unicode_literals
from __future__ import division
from __future__ import absolute_import
from __future__ import print_function

import tensorflow as tf
import numpy as np

from sklearn.metrics import accuracy_score

# %%
import tensorflow.contrib.layers as tcl
class SSL:
    def __init__(self):
        # classifier params
        self.hidden_size = 500
        self.num_labels = 10
        
        # encode & decoder params
        self.z_dim = 50
        self.x_dim = 28*28
        
        # training
        self.learning_rate = 1e-3
        
        self._build_graph()
        self._build_train_op()
        self.check_parameters()
    
    def check_parameters(self):
        for var in tf.trainable_variables():
            print('%s: %s' % (var.name, var.get_shape()))
        print()
    
    def classify(self, x, reuse = False):
        with tf.variable_scope('classifier', reuse = reuse):
            h = tcl.fully_connected(x, self.hidden_size, activation_fn = tf.nn.softplus)
            y = tcl.fully_connected(h, self.num_labels, activation_fn = tf.nn.softplus)
        return y
    
    def reparameterize(self, mu, logvar):
        batch_size = tf.shape(mu)[0]
        std = tf.exp(logvar * 0.5)
        eps = tf.random_normal([batch_size, self.z_dim])
        z = mu + eps * std
        return z
    
    def encode(self, x, y, reuse = False):
        with tf.variable_scope('encoder', reuse = reuse):
            concat = tf.concat([x, y], 1)
            h = tcl.fully_connected(concat, self.hidden_size, activation_fn = tf.nn.softplus)

            mu     = tcl.fully_connected(h, self.z_dim, activation_fn = None)
            logvar = tcl.fully_connected(h, self.z_dim, activation_fn = None)

            z = self.reparameterize(mu, logvar)
        return z, mu, logvar
    
    def decode(self, z, y, reuse = False):
        with tf.variable_scope('decoder', reuse = reuse):
            concat = tf.concat([z, y], 1)
            h = tcl.fully_connected(concat, self.hidden_size, activation_fn = tf.nn.softplus)
            x_recon = tcl.fully_connected(h, self.x_dim, activation_fn = tf.nn.sigmoid)
        return x_recon
    
    def L(self, x, x_recon, y, mu, logvar):
        '''
            calculate the ELBO with SGVB.
                where E_q(z)[ log p(x,y|z)] is estimated with 
                    sum_1^L log p(x,y|z)
                here, we set L = 1, thus
                
            L(x, y) = E_q(z)[ log p(x,y|z)] - KL(q(z)||p(z))
                    ~ log p(x,y|z) - KL(q(z)||p(z))
                    = log p(x|z) + log p(y) - KL(q(z)||p(z))
            
            since we use bernoulli decoder, 
                log p(x|z) = log p^(x)(1-p)^(1-x)
                           = x log p + (1-x) log (1-p)
            here p = x_recon, x = x
            
            the polynomial dist could be emitted, because 
                log p(y) = log 1/N = const
                
            NOTE:
                the return value is - L, here L refers to loglikihood
        '''
        def KLD(mu, logvar):
            return - 0.5*(1+logvar-tf.square(mu)-tf.exp(logvar))
        def log_bernoulli(p, x):
            epsilon = 1e-8
            return x * tf.log(p + epsilon) + (1-x) * tf.log(1-p + epsilon)
        
        # uniform dist
        prior_y = (1. / self.num_labels) * tf.ones_like( y )
        logpy = - tf.nn.softmax_cross_entropy_with_logits(labels = prior_y, logits = y )

        # (batch_size, z_dim) -> batch_size,
        kldloss = tf.reduce_sum(KLD(mu, logvar),1)
        # (batch_size, 784) -> batch_size,
        logpx   = tf.reduce_sum(log_bernoulli(x_recon, x), 1)
        
        loss = kldloss - logpx - logpy
        return loss
    
    def _build_graph(self, reuse = False):
        self.x_l = tf.placeholder(tf.float32, shape = (None, self.x_dim))
        self.y_l = tf.placeholder(tf.int32, shape = (None, ))
        self.x_u = tf.placeholder(tf.float32, shape = (None, self.x_dim))
        
        # classifier, labelled & unlabelled
        scores_l = self.classify(self.x_l, reuse = reuse)
        scores_u = self.classify(self.x_u, reuse = True)
        self.pred_y = tf.argmax(scores_u, 1)
        y_u_prob = tf.nn.softmax(scores_u, dim=-1)
        
        y_l_onehot =  tcl.one_hot_encoding(self.y_l, num_classes = self.num_labels)
        
        # encoder, labelled data
        z_l, mu_l, logvar_l = self.encode(self.x_l, y_l_onehot, reuse = reuse)
            
        # encoder, unlabelled data
        z_u      = [0]*self.num_labels
        mu_u     = [0]*self.num_labels
        logvar_u = [0]*self.num_labels
        y_us = [0]*self.num_labels
        for i in range(self.num_labels):
            _y = i * tf.ones([tf.shape(self.x_u)[0]], tf.int32)
            y_us[i] = tcl.one_hot_encoding(_y, num_classes = self.num_labels)
            z_u[i], mu_u[i], logvar_u[i] = self.encode(self.x_u, y_us[i], reuse = True)
        
        # decoder, labelled data
        x_recon = self.decode(z_l, scores_l, reuse = reuse)
        
        # decoder, unlabelled data
        x_recon_u = [0]*self.num_labels
        for i in range(self.num_labels):
            x_recon_u[i] = self.decode(z_u[i], y_us[i], reuse = True)
            
        # loss of classifier
        self.loss_clf = tf.nn.sparse_softmax_cross_entropy_with_logits(\
                        labels = self.y_l, logits = scores_l)
        # loss of labelled data, refered as L(x, y)
        self.loss_l = self.L(self.x_l, x_recon, y_l_onehot, mu_l, logvar_l);
        
        # loss of unlabelled data, refered as U(x)
        self.loss_u = 0;
        for i in range(self.num_labels):
            if i==0:
                _loss_u = self.L(self.x_u, x_recon_u[i], y_us[i], mu_u[i], logvar_u[i])
                self.loss_u = tf.expand_dims(_loss_u, 1)
            else:
                _loss_u = self.L(self.x_u, x_recon_u[i], y_us[i], mu_u[i], logvar_u[i])
                _loss_u = tf.expand_dims(_loss_u, 1)
                self.loss_u = tf.concat([self.loss_u, _loss_u], 1)

        # add the H(q(y|x))
        self.loss_u = tf.multiply(y_u_prob, tf.subtract(self.loss_u, -tf.log(y_u_prob)) )
        self.loss_u = tf.reduce_sum(self.loss_u, 1)

        print('loss_u  : '+str(self.loss_u.shape))
        print('loss_l  : '+str(self.loss_l.shape))
        print('loss_clf: '+str(self.loss_clf.shape))

        alpha = 0.1*100
        self.loss_clf = tf.reduce_mean(self.loss_clf, 0)
        self.loss_l   = tf.reduce_mean(self.loss_l,   0)
        self.loss_u   = tf.reduce_mean(self.loss_u,   0)
        self.loss = self.loss_l + self.loss_u + alpha * self.loss_clf
#         self.loss = self.loss_clf
    
    def _build_train_op(self):
        self.global_step = tf.Variable(0, name="global_step", trainable = False)
        optimizer = tf.train.AdamOptimizer(self.learning_rate)
        grads_and_vars = optimizer.compute_gradients(self.loss)
        def ClipIfNotNone(grad):
            if grad is None:
                return grad
            return tf.clip_by_value(grad, -1, 1)
        capped_gvs = [(ClipIfNotNone(grad), var) for grad, var in grads_and_vars]
        self.train_op = optimizer.apply_gradients(capped_gvs, self.global_step)
        
    def predict(self, x, sess):
        feed_dict = {
            self.x_u: x,
        }
        pred = sess.run([self.pred_y], feed_dict = feed_dict)[0]
        return pred

# %%
'''
    the following 3 functions came from the original implementation by D.P. Kingma
        @https://github.com/dpkingma/nips14-ssl
    these function are slightly modified for convenience
'''
import cPickle
import gzip
import random
import numpy as np
MNIST_PATH = './data/mnist_28.pkl.gz'

def load_mnist(path):
    f = gzip.open(path, 'rb')
    train, valid, test = cPickle.load(f)
    f.close()
    train_x, train_y = train
    valid_x, valid_y = valid
    test_x,  test_y  = test        
    return train_x, train_y, valid_x, valid_y, test_x, test_y

# Loads data where data is split into class labels
def load_mnist_split(path = MNIST_PATH):
    train_x, train_y, valid_x, valid_y, test_x, test_y = load_mnist(path)
    
    def split_by_class(x, y, num_classes):
        result_x = [0]*num_classes
        result_y = [0]*num_classes
        for i in range(num_classes):
            idx_i = np.where(y == i)[0]
            result_x[i] = x[idx_i]
            result_y[i] = y[idx_i]
        return result_x, result_y
    
    train_x, train_y = split_by_class(train_x, train_y, 10)
    return train_x, train_y, valid_x, valid_y, test_x, test_y

def create_semisupervised(x, y, n_labeled):
    n_x = x[0].shape[0]
    n_classes = 10
    if n_labeled % n_classes != 0: 
        raise("n_labeled (wished number of labeled samples) not divisible by n_classes (number of classes)")
    n_labels_per_class = n_labeled//n_classes
    x_labeled = [0]*n_classes
    x_unlabeled = [0]*n_classes
    y_labeled = [0]*n_classes
    y_unlabeled = [0]*n_classes
    for i in range(n_classes):
        idx = range(x[i].shape[0])
        random.shuffle(idx)
        x_labeled[i]   = x[i][idx[:n_labels_per_class]]
        y_labeled[i]   = y[i][idx[:n_labels_per_class]]
        x_unlabeled[i] = x[i][idx[n_labels_per_class:]]
        y_unlabeled[i] = y[i][idx[n_labels_per_class:]]
    return np.vstack(x_labeled), np.hstack(y_labeled), np.vstack(x_unlabeled), np.hstack(y_unlabeled)

# %%
def batch_generator(data, batch_size, num_epoch, shuffle = True):
    data = list(data)
    data = np.array(data)
    data_size = data.shape[0]
    num_batches_per_epoch = (data_size + batch_size - 1)//batch_size
    for epoch in range(num_epoch):
        if shuffle:
            shuffle_indices = np.random.permutation(np.arange(data_size))
            shuffled_data = data[shuffle_indices]
        else:
            shuffled_data = data

        for batch_idx in range(num_batches_per_epoch):
            start_idx = batch_idx * batch_size
            end_idx   = min((batch_idx + 1)*batch_size, data_size)
            yield(shuffled_data[start_idx:end_idx])
            
import time
def time_since(since):
    now = time.time()
    s = now - since
    m = s // 60
    s -= 60 * m

    return "%d m %d s" % (m, s)

# %%
'''
    here are the config params for the experiment.
'''
data_size = 50000
n_batch_size = 100
n_labelled = 100
n_epoch = 100
max_iter = n_epoch*(data_size-n_labelled)//n_batch_size

# load data from mnist
train_x, train_y, valid_x, valid_y, test_x, test_y = load_mnist_split()
# split training set
x_l, y_l, x_u, y_u = create_semisupervised(train_x, train_y, n_labelled)
l_batch_gen = batch_generator(zip(x_l, y_l), n_batch_size, max_iter)
u_batch_gen = batch_generator(zip(x_u), n_batch_size, n_epoch)

# Set config for tensorflow session.
tf_config = tf.ConfigProto(
    device_count = {'GPU': 1}, # single gpu
)
tf_config.gpu_options.allow_growth=True
with tf.Session(config = tf_config) as sess:
    model = SSL()
    sess.run(tf.global_variables_initializer())

    eval_train = [model.train_op, model.global_step]
    eval_loss  = [model.loss, model.loss_l, model.loss_u, model.loss_clf]
    
    start = time.time()
    for l_batch, u_batch in zip(l_batch_gen, u_batch_gen):
        x_l, y_l = zip(*l_batch)
        x_u = zip(*u_batch)[0]

        feed_dict = {
            model.x_l: x_l,
            model.y_l: y_l,

            model.x_u: x_u,
        }
        _, step = sess.run(eval_train, feed_dict = feed_dict)
        if step % 500 == 0:
            loss, loss_l, loss_u, loss_clf = sess.run(eval_loss, feed_dict = feed_dict)

            pred_valid = model.predict(valid_x, sess)
            pred_test  = model.predict(test_x,  sess)
            accuracy_valid = accuracy_score(valid_y, pred_valid)
            accuracy_test  = accuracy_score(test_y,  pred_test)
            
            print('time: %s' % time_since(start))
            print(' Iteration %d/%d'    % (step, max_iter))
            print('  labelled loss: %.2f' % loss_l)
            print('unlabelled loss: %.2f' % loss_u)
            print('classifier loss: %.2f' % loss_clf)
            print('     total loss: %.2f' % loss)
            print(' valid accuracy: %.2f' % accuracy_valid)
            print('  test accuracy: %.2f' % accuracy_test)
            print()
# Out:
# loss_u  : (?,)
# loss_l  : (?,)
# loss_clf: (?,)
# classifier/fully_connected/weights:0: (784, 500)
# classifier/fully_connected/biases:0: (500,)
# classifier/fully_connected_1/weights:0: (500, 10)
# classifier/fully_connected_1/biases:0: (10,)
# encoder/fully_connected/weights:0: (794, 500)
# encoder/fully_connected/biases:0: (500,)
# encoder/fully_connected_1/weights:0: (500, 50)
# encoder/fully_connected_1/biases:0: (50,)
# encoder/fully_connected_2/weights:0: (500, 50)
# encoder/fully_connected_2/biases:0: (50,)
# decoder/fully_connected/weights:0: (60, 500)
# decoder/fully_connected/biases:0: (500,)
# decoder/fully_connected_1/weights:0: (500, 784)
# decoder/fully_connected_1/biases:0: (784,)
#
# time: 0 m 21 s
#  Iteration 500/49900
#   labelled loss: 66.78
# unlabelled loss: 144.59
# classifier loss: 0.00
#      total loss: 211.43
#  valid accuracy: 0.70
#   test accuracy: 0.68
#
# time: 0 m 34 s
#  Iteration 1000/49900
#   labelled loss: 60.92
# unlabelled loss: 127.46
# classifier loss: 0.00
#      total loss: 188.40
#  valid accuracy: 0.70
#   test accuracy: 0.68
#
# time: 0 m 46 s
#  Iteration 1500/49900
#   labelled loss: 58.14
# unlabelled loss: 125.70
# classifier loss: 0.00
#      total loss: 183.86
#  valid accuracy: 0.69
#   test accuracy: 0.67
#
# time: 0 m 59 s
#  Iteration 2000/49900
#   labelled loss: 56.02
# unlabelled loss: 122.00
# classifier loss: 0.00
#      total loss: 178.03
#  valid accuracy: 0.70
#   test accuracy: 0.67
#
# time: 1 m 12 s
#  Iteration 2500/49900
#   labelled loss: 54.71
# unlabelled loss: 119.19
# classifier loss: 0.00
#      total loss: 173.92
#  valid accuracy: 0.70
#   test accuracy: 0.68
#
# time: 1 m 24 s
#  Iteration 3000/49900
#   labelled loss: 53.93
# unlabelled loss: 117.99
# classifier loss: 0.00
#      total loss: 171.93
#  valid accuracy: 0.71
#   test accuracy: 0.69
#
# time: 1 m 37 s
#  Iteration 3500/49900
#   labelled loss: 53.52
# unlabelled loss: 115.14
# classifier loss: 0.00
#      total loss: 168.67
#  valid accuracy: 0.71
#   test accuracy: 0.68
#
# time: 1 m 50 s
#  Iteration 4000/49900
#   labelled loss: 52.85
# unlabelled loss: 115.15
# classifier loss: 0.00
#      total loss: 168.00
#  valid accuracy: 0.72
#   test accuracy: 0.69
#
# time: 2 m 2 s
#  Iteration 4500/49900
#   labelled loss: 53.00
# unlabelled loss: 113.16
# classifier loss: 0.00
#      total loss: 166.18
#  valid accuracy: 0.72
#   test accuracy: 0.70
#
# time: 2 m 15 s
#  Iteration 5000/49900
#   labelled loss: 52.39
# unlabelled loss: 108.86
# classifier loss: 0.00
#      total loss: 161.26
#  valid accuracy: 0.72
#   test accuracy: 0.70
#
# time: 2 m 28 s
#  Iteration 5500/49900
#   labelled loss: 52.23
# unlabelled loss: 106.42
# classifier loss: 0.00
#      total loss: 158.66
#  valid accuracy: 0.73
#   test accuracy: 0.70
#
# time: 2 m 40 s
#  Iteration 6000/49900
#   labelled loss: 52.04
# unlabelled loss: 107.87
# classifier loss: 0.00
#      total loss: 159.91
#  valid accuracy: 0.74
#   test accuracy: 0.71
#
# time: 2 m 53 s
#  Iteration 6500/49900
#   labelled loss: 51.98
# unlabelled loss: 114.29
# classifier loss: 0.00
#      total loss: 166.27
#  valid accuracy: 0.73
#   test accuracy: 0.71
#
# time: 3 m 6 s
#  Iteration 7000/49900
#   labelled loss: 51.76
# unlabelled loss: 106.76
# classifier loss: 0.00
#      total loss: 158.52
#  valid accuracy: 0.74
#   test accuracy: 0.71
#
# time: 3 m 18 s
#  Iteration 7500/49900
#   labelled loss: 51.76
# unlabelled loss: 109.03
# classifier loss: 0.00
#      total loss: 160.80
#  valid accuracy: 0.74
#   test accuracy: 0.72
#
# time: 3 m 31 s
#  Iteration 8000/49900
#   labelled loss: 51.67
# unlabelled loss: 105.86
# classifier loss: 0.00
#      total loss: 157.54
#  valid accuracy: 0.75
#   test accuracy: 0.72
#
# time: 3 m 44 s
#  Iteration 8500/49900
#   labelled loss: 51.55
# unlabelled loss: 110.57
# classifier loss: 0.00
#      total loss: 162.12
#  valid accuracy: 0.75
#   test accuracy: 0.73
#
# time: 3 m 56 s
#  Iteration 9000/49900
#   labelled loss: 51.53
# unlabelled loss: 109.74
# classifier loss: 0.00
#      total loss: 161.27
#  valid accuracy: 0.76
#   test accuracy: 0.74
#
# time: 4 m 9 s
#  Iteration 9500/49900
#   labelled loss: 51.51
# unlabelled loss: 105.40
# classifier loss: 0.00
#      total loss: 156.91
#  valid accuracy: 0.76
#   test accuracy: 0.74
#
# time: 4 m 22 s
#  Iteration 10000/49900
#   labelled loss: 51.45
# unlabelled loss: 105.27
# classifier loss: 0.00
#      total loss: 156.73
#  valid accuracy: 0.76
#   test accuracy: 0.75
#
# time: 4 m 34 s
#  Iteration 10500/49900
#   labelled loss: 51.44
# unlabelled loss: 108.38
# classifier loss: 0.00
#      total loss: 159.83
#  valid accuracy: 0.76
#   test accuracy: 0.74
#
# time: 4 m 47 s
#  Iteration 11000/49900
#   labelled loss: 51.31
# unlabelled loss: 107.10
# classifier loss: 0.00
#      total loss: 158.41
#  valid accuracy: 0.77
#   test accuracy: 0.75
#
# time: 5 m 0 s
#  Iteration 11500/49900
#   labelled loss: 51.34
# unlabelled loss: 108.80
# classifier loss: 0.00
#      total loss: 160.15
#  valid accuracy: 0.77
#   test accuracy: 0.75
#
# time: 5 m 12 s
#  Iteration 12000/49900
#   labelled loss: 51.23
# unlabelled loss: 106.11
# classifier loss: 0.00
#      total loss: 157.34
#  valid accuracy: 0.78
#   test accuracy: 0.76
#
# time: 5 m 25 s
#  Iteration 12500/49900
#   labelled loss: 51.26
# unlabelled loss: 106.69
# classifier loss: 0.00
#      total loss: 157.95
#  valid accuracy: 0.78
#   test accuracy: 0.77
#
# time: 5 m 38 s
#  Iteration 13000/49900
#   labelled loss: 51.26
# unlabelled loss: 102.12
# classifier loss: 0.00
#      total loss: 153.39
#  valid accuracy: 0.78
#   test accuracy: 0.77
#
# time: 5 m 50 s
#  Iteration 13500/49900
#   labelled loss: 51.20
# unlabelled loss: 105.26
# classifier loss: 0.00
#      total loss: 156.46
#  valid accuracy: 0.79
#   test accuracy: 0.77
#
# time: 6 m 3 s
#  Iteration 14000/49900
#   labelled loss: 51.19
# unlabelled loss: 104.60
# classifier loss: 0.00
#      total loss: 155.79
#  valid accuracy: 0.79
#   test accuracy: 0.77
#
# time: 6 m 16 s
#  Iteration 14500/49900
#   labelled loss: 51.19
# unlabelled loss: 99.71
# classifier loss: 0.00
#      total loss: 150.90
#  valid accuracy: 0.79
#   test accuracy: 0.77
#
# time: 6 m 28 s
#  Iteration 15000/49900
#   labelled loss: 51.15
# unlabelled loss: 105.22
# classifier loss: 0.00
#      total loss: 156.37
#  valid accuracy: 0.79
#   test accuracy: 0.78
#
# time: 6 m 41 s
#  Iteration 15500/49900
#   labelled loss: 51.16
# unlabelled loss: 107.00
# classifier loss: 0.00
#      total loss: 158.17
#  valid accuracy: 0.80
#   test accuracy: 0.78
#
# time: 6 m 54 s
#  Iteration 16000/49900
#   labelled loss: 51.11
# unlabelled loss: 104.51
# classifier loss: 0.00
#      total loss: 155.62
#  valid accuracy: 0.80
#   test accuracy: 0.79
#
# time: 7 m 6 s
#  Iteration 16500/49900
#   labelled loss: 51.09
# unlabelled loss: 104.61
# classifier loss: 0.00
#      total loss: 155.71
#  valid accuracy: 0.80
#   test accuracy: 0.79
#
# time: 7 m 19 s
#  Iteration 17000/49900
#   labelled loss: 51.10
# unlabelled loss: 106.77
# classifier loss: 0.00
#      total loss: 157.88
#  valid accuracy: 0.80
#   test accuracy: 0.79
#
# time: 7 m 32 s
#  Iteration 17500/49900
#   labelled loss: 51.06
# unlabelled loss: 104.87
# classifier loss: 0.00
#      total loss: 155.93
#  valid accuracy: 0.81
#   test accuracy: 0.79
#
# time: 7 m 44 s
#  Iteration 18000/49900
#   labelled loss: 51.08
# unlabelled loss: 104.82
# classifier loss: 0.00
#      total loss: 155.90
#  valid accuracy: 0.81
#   test accuracy: 0.80
#
# time: 7 m 57 s
#  Iteration 18500/49900
#   labelled loss: 51.06
# unlabelled loss: 106.74
# classifier loss: 0.00
#      total loss: 157.80
#  valid accuracy: 0.81
#   test accuracy: 0.80
#
# time: 8 m 10 s
#  Iteration 19000/49900
#   labelled loss: 51.07
# unlabelled loss: 105.15
# classifier loss: 0.00
#      total loss: 156.23
#  valid accuracy: 0.81
#   test accuracy: 0.80
#
# time: 8 m 23 s
#  Iteration 19500/49900
#   labelled loss: 51.00
# unlabelled loss: 106.84
# classifier loss: 0.00
#      total loss: 157.84
#  valid accuracy: 0.81
#   test accuracy: 0.80
#
# time: 8 m 35 s
#  Iteration 20000/49900
#   labelled loss: 51.05
# unlabelled loss: 100.11
# classifier loss: 0.00
#      total loss: 151.17
#  valid accuracy: 0.81
#   test accuracy: 0.80
#
# time: 8 m 48 s
#  Iteration 20500/49900
#   labelled loss: 51.06
# unlabelled loss: 98.06
# classifier loss: 0.00
#      total loss: 149.12
#  valid accuracy: 0.82
#   test accuracy: 0.80
#
# time: 9 m 0 s
#  Iteration 21000/49900
#   labelled loss: 51.02
# unlabelled loss: 103.41
# classifier loss: 0.00
#      total loss: 154.44
#  valid accuracy: 0.82
#   test accuracy: 0.80
#
# time: 9 m 13 s
#  Iteration 21500/49900
#   labelled loss: 51.02
# unlabelled loss: 103.18
# classifier loss: 0.00
#      total loss: 154.21
#  valid accuracy: 0.82
#   test accuracy: 0.81
#
# time: 9 m 26 s
#  Iteration 22000/49900
#   labelled loss: 51.01
# unlabelled loss: 102.38
# classifier loss: 0.00
#      total loss: 153.40
#  valid accuracy: 0.83
#   test accuracy: 0.81
#
# time: 9 m 38 s
#  Iteration 22500/49900
#   labelled loss: 50.98
# unlabelled loss: 101.56
# classifier loss: 0.00
#      total loss: 152.54
#  valid accuracy: 0.83
#   test accuracy: 0.81
#
# time: 9 m 51 s
#  Iteration 23000/49900
#   labelled loss: 50.99
# unlabelled loss: 104.31
# classifier loss: 0.00
#      total loss: 155.30
#  valid accuracy: 0.83
#   test accuracy: 0.82
#
# time: 10 m 4 s
#  Iteration 23500/49900
#   labelled loss: 51.03
# unlabelled loss: 101.90
# classifier loss: 0.00
#      total loss: 152.93
#  valid accuracy: 0.83
#   test accuracy: 0.82
#
# time: 10 m 17 s
#  Iteration 24000/49900
#   labelled loss: 50.97
# unlabelled loss: 101.17
# classifier loss: 0.00
#      total loss: 152.15
#  valid accuracy: 0.83
#   test accuracy: 0.82
#
# time: 10 m 29 s
#  Iteration 24500/49900
#   labelled loss: 50.95
# unlabelled loss: 100.81
# classifier loss: 0.00
#      total loss: 151.76
#  valid accuracy: 0.83
#   test accuracy: 0.82
#
# time: 10 m 42 s
#  Iteration 25000/49900
#   labelled loss: 50.97
# unlabelled loss: 98.50
# classifier loss: 0.00
#      total loss: 149.48
#  valid accuracy: 0.84
#   test accuracy: 0.82
#
# time: 10 m 55 s
#  Iteration 25500/49900
#   labelled loss: 50.92
# unlabelled loss: 102.91
# classifier loss: 0.00
#      total loss: 153.84
#  valid accuracy: 0.84
#   test accuracy: 0.83
#
# time: 11 m 7 s
#  Iteration 26000/49900
#   labelled loss: 50.92
# unlabelled loss: 103.08
# classifier loss: 0.00
#      total loss: 154.01
#  valid accuracy: 0.84
#   test accuracy: 0.82
#
# time: 11 m 20 s
#  Iteration 26500/49900
#   labelled loss: 50.95
# unlabelled loss: 102.80
# classifier loss: 0.00
#      total loss: 153.76
#  valid accuracy: 0.84
#   test accuracy: 0.82
#
# time: 11 m 33 s
#  Iteration 27000/49900
#   labelled loss: 50.95
# unlabelled loss: 102.26
# classifier loss: 0.00
#      total loss: 153.21
#  valid accuracy: 0.85
#   test accuracy: 0.83
#
# time: 11 m 45 s
#  Iteration 27500/49900
#   labelled loss: 50.96
# unlabelled loss: 102.53
# classifier loss: 0.00
#      total loss: 153.49
#  valid accuracy: 0.85
#   test accuracy: 0.83
#
# time: 11 m 58 s
#  Iteration 28000/49900
#   labelled loss: 50.93
# unlabelled loss: 99.19
# classifier loss: 0.00
#      total loss: 150.12
#  valid accuracy: 0.85
#   test accuracy: 0.83
#
# time: 12 m 11 s
#  Iteration 28500/49900
#   labelled loss: 50.91
# unlabelled loss: 99.51
# classifier loss: 0.00
#      total loss: 150.41
#  valid accuracy: 0.85
#   test accuracy: 0.84
#
# time: 12 m 23 s
#  Iteration 29000/49900
#   labelled loss: 50.96
# unlabelled loss: 99.23
# classifier loss: 0.00
#      total loss: 150.20
#  valid accuracy: 0.85
#   test accuracy: 0.83
#
# time: 12 m 36 s
#  Iteration 29500/49900
#   labelled loss: 50.91
# unlabelled loss: 100.78
# classifier loss: 0.00
#      total loss: 151.69
#  valid accuracy: 0.85
#   test accuracy: 0.84
#
# time: 12 m 49 s
#  Iteration 30000/49900
#   labelled loss: 50.91
# unlabelled loss: 100.89
# classifier loss: 0.00
#      total loss: 151.80
#  valid accuracy: 0.85
#   test accuracy: 0.84
#
# time: 13 m 1 s
#  Iteration 30500/49900
#   labelled loss: 50.89
# unlabelled loss: 100.03
# classifier loss: 0.00
#      total loss: 150.92
#  valid accuracy: 0.86
#   test accuracy: 0.84
#
# time: 13 m 14 s
#  Iteration 31000/49900
#   labelled loss: 50.91
# unlabelled loss: 96.82
# classifier loss: 0.00
#      total loss: 147.73
#  valid accuracy: 0.86
#   test accuracy: 0.84
#
# time: 13 m 27 s
#  Iteration 31500/49900
#   labelled loss: 50.92
# unlabelled loss: 101.04
# classifier loss: 0.00
#      total loss: 151.96
#  valid accuracy: 0.86
#   test accuracy: 0.84
#
# time: 13 m 39 s
#  Iteration 32000/49900
#   labelled loss: 50.94
# unlabelled loss: 99.11
# classifier loss: 0.00
#      total loss: 150.04
#  valid accuracy: 0.86
#   test accuracy: 0.84
#
# time: 13 m 52 s
#  Iteration 32500/49900
#   labelled loss: 50.87
# unlabelled loss: 102.01
# classifier loss: 0.00
#      total loss: 152.87
#  valid accuracy: 0.86
#   test accuracy: 0.84
#
# time: 14 m 5 s
#  Iteration 33000/49900
#   labelled loss: 50.89
# unlabelled loss: 100.70
# classifier loss: 0.00
#      total loss: 151.59
#  valid accuracy: 0.86
#   test accuracy: 0.85
#
# time: 14 m 17 s
#  Iteration 33500/49900
#   labelled loss: 50.93
# unlabelled loss: 101.36
# classifier loss: 0.00
#      total loss: 152.29
#  valid accuracy: 0.86
#   test accuracy: 0.85
#
# time: 14 m 30 s
#  Iteration 34000/49900
#   labelled loss: 50.87
# unlabelled loss: 102.30
# classifier loss: 0.00
#      total loss: 153.17
#  valid accuracy: 0.86
#   test accuracy: 0.85
#
# time: 14 m 43 s
#  Iteration 34500/49900
#   labelled loss: 50.87
# unlabelled loss: 98.14
# classifier loss: 0.00
#      total loss: 149.01
#  valid accuracy: 0.86
#   test accuracy: 0.85
#
# time: 14 m 55 s
#  Iteration 35000/49900
#   labelled loss: 50.87
# unlabelled loss: 95.59
# classifier loss: 0.00
#      total loss: 146.46
#  valid accuracy: 0.86
#   test accuracy: 0.85
#
# time: 15 m 8 s
#  Iteration 35500/49900
#   labelled loss: 50.87
# unlabelled loss: 97.45
# classifier loss: 0.00
#      total loss: 148.32
#  valid accuracy: 0.87
#   test accuracy: 0.85
#
# time: 15 m 21 s
#  Iteration 36000/49900
#   labelled loss: 50.87
# unlabelled loss: 98.66
# classifier loss: 0.00
#      total loss: 149.53
#  valid accuracy: 0.87
#   test accuracy: 0.85
#
# time: 15 m 33 s
#  Iteration 36500/49900
#   labelled loss: 50.85
# unlabelled loss: 103.19
# classifier loss: 0.00
#      total loss: 154.04
#  valid accuracy: 0.87
#   test accuracy: 0.85
#
# time: 15 m 46 s
#  Iteration 37000/49900
#   labelled loss: 50.86
# unlabelled loss: 97.98
# classifier loss: 0.00
#      total loss: 148.84
#  valid accuracy: 0.87
#   test accuracy: 0.85
#
# time: 15 m 59 s
#  Iteration 37500/49900
#   labelled loss: 50.89
# unlabelled loss: 100.91
# classifier loss: 0.00
#      total loss: 151.80
#  valid accuracy: 0.87
#   test accuracy: 0.85
#
# time: 16 m 12 s
#  Iteration 38000/49900
#   labelled loss: 50.84
# unlabelled loss: 100.96
# classifier loss: 0.00
#      total loss: 151.80
#  valid accuracy: 0.87
#   test accuracy: 0.85
#
# time: 16 m 24 s
#  Iteration 38500/49900
#   labelled loss: 50.83
# unlabelled loss: 97.43
# classifier loss: 0.00
#      total loss: 148.26
#  valid accuracy: 0.87
#   test accuracy: 0.86
#
# time: 16 m 37 s
#  Iteration 39000/49900
#   labelled loss: 50.84
# unlabelled loss: 103.64
# classifier loss: 0.00
#      total loss: 154.48
#  valid accuracy: 0.87
#   test accuracy: 0.86
#
# time: 16 m 50 s
#  Iteration 39500/49900
#   labelled loss: 50.84
# unlabelled loss: 100.61
# classifier loss: 0.00
#      total loss: 151.45
#  valid accuracy: 0.87
#   test accuracy: 0.86
#
# time: 17 m 2 s
#  Iteration 40000/49900
#   labelled loss: 50.83
# unlabelled loss: 94.24
# classifier loss: 0.00
#      total loss: 145.07
#  valid accuracy: 0.88
#   test accuracy: 0.86
#
# time: 17 m 15 s
#  Iteration 40500/49900
#   labelled loss: 50.85
# unlabelled loss: 100.26
# classifier loss: 0.00
#      total loss: 151.11
#  valid accuracy: 0.88
#   test accuracy: 0.86
#
# time: 17 m 28 s
#  Iteration 41000/49900
#   labelled loss: 50.86
# unlabelled loss: 96.95
# classifier loss: 0.00
#      total loss: 147.82
#  valid accuracy: 0.87
#   test accuracy: 0.86
#
# time: 17 m 41 s
#  Iteration 41500/49900
#   labelled loss: 50.82
# unlabelled loss: 100.29
# classifier loss: 0.00
#      total loss: 151.10
#  valid accuracy: 0.88
#   test accuracy: 0.86
#
# time: 17 m 53 s
#  Iteration 42000/49900
#   labelled loss: 50.85
# unlabelled loss: 98.95
# classifier loss: 0.00
#      total loss: 149.79
#  valid accuracy: 0.88
#   test accuracy: 0.86
#
# time: 18 m 6 s
#  Iteration 42500/49900
#   labelled loss: 50.80
# unlabelled loss: 100.63
# classifier loss: 0.00
#      total loss: 151.43
#  valid accuracy: 0.88
#   test accuracy: 0.86
#
# time: 18 m 19 s
#  Iteration 43000/49900
#   labelled loss: 50.84
# unlabelled loss: 101.69
# classifier loss: 0.00
#      total loss: 152.53
#  valid accuracy: 0.88
#   test accuracy: 0.86
#
# time: 18 m 31 s
#  Iteration 43500/49900
#   labelled loss: 51.12
# unlabelled loss: 95.50
# classifier loss: 0.00
#      total loss: 146.63
#  valid accuracy: 0.87
#   test accuracy: 0.86
#
# time: 18 m 44 s
#  Iteration 44000/49900
#   labelled loss: 50.82
# unlabelled loss: 100.82
# classifier loss: 0.00
#      total loss: 151.64
#  valid accuracy: 0.88
#   test accuracy: 0.86
#
# time: 18 m 57 s
#  Iteration 44500/49900
#   labelled loss: 50.80
# unlabelled loss: 100.95
# classifier loss: 0.00
#      total loss: 151.75
#  valid accuracy: 0.88
#   test accuracy: 0.86
#
# time: 19 m 10 s
#  Iteration 45000/49900
#   labelled loss: 50.81
# unlabelled loss: 95.97
# classifier loss: 0.00
#      total loss: 146.79
#  valid accuracy: 0.88
#   test accuracy: 0.86
#
# time: 19 m 22 s
#  Iteration 45500/49900
#   labelled loss: 50.81
# unlabelled loss: 103.85
# classifier loss: 0.00
#      total loss: 154.67
#  valid accuracy: 0.88
#   test accuracy: 0.87
#
# time: 19 m 35 s
#  Iteration 46000/49900
#   labelled loss: 50.79
# unlabelled loss: 99.14
# classifier loss: 0.00
#      total loss: 149.93
#  valid accuracy: 0.88
#   test accuracy: 0.86
#
# time: 19 m 48 s
#  Iteration 46500/49900
#   labelled loss: 50.77
# unlabelled loss: 99.05
# classifier loss: 0.00
#      total loss: 149.82
#  valid accuracy: 0.88
#   test accuracy: 0.86
#
# time: 20 m 0 s
#  Iteration 47000/49900
#   labelled loss: 50.82
# unlabelled loss: 100.15
# classifier loss: 0.00
#      total loss: 150.97
#  valid accuracy: 0.88
#   test accuracy: 0.87
#
# time: 20 m 13 s
#  Iteration 47500/49900
#   labelled loss: 50.82
# unlabelled loss: 98.54
# classifier loss: 0.00
#      total loss: 149.36
#  valid accuracy: 0.88
#   test accuracy: 0.86
#
# time: 20 m 26 s
#  Iteration 48000/49900
#   labelled loss: 50.81
# unlabelled loss: 101.65
# classifier loss: 0.00
#      total loss: 152.46
#  valid accuracy: 0.88
#   test accuracy: 0.86
#
# time: 20 m 38 s
#  Iteration 48500/49900
#   labelled loss: 50.79
# unlabelled loss: 98.75
# classifier loss: 0.00
#      total loss: 149.54
#  valid accuracy: 0.88
#   test accuracy: 0.86
#
# time: 20 m 51 s
#  Iteration 49000/49900
#   labelled loss: 50.80
# unlabelled loss: 94.93
# classifier loss: 0.00
#      total loss: 145.73
#  valid accuracy: 0.88
#   test accuracy: 0.86
#
# time: 21 m 4 s
#  Iteration 49500/49900
#   labelled loss: 50.78
# unlabelled loss: 97.88
# classifier loss: 0.00
#      total loss: 148.67
#  valid accuracy: 0.88
#   test accuracy: 0.86
